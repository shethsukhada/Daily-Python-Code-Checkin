# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('IceCreamDataSet.xlsx')

# %%
df.head()
# Out:
#           Customer       Date     Flavor  Revenue  Profit
# 0  Dennis Perelman 2018-03-28  Chocolate      2.0     1.0
# 1       Don Frazon 2018-03-28    Vanilla      2.0     1.0
# 2    Drew Roulette 2018-03-28    Vanilla      2.0     1.0
# 3    Erin Davidson 2018-03-28    Vanilla      2.0     1.0
# 4   Ian Richardson 2018-03-28    Vanilla      2.0     1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 5 columns):
# Customer    86 non-null object
# Date        86 non-null datetime64[ns]
# Flavor      86 non-null object
# Revenue     83 non-null float64
# Profit      82 non-null float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 3.4+ KB

# %%
df.describe()
# Out:
#          Revenue     Profit
# count  83.000000  82.000000
# mean    4.060241   2.987805
# std     0.985868   0.904296
# min     2.000000   1.000000
# 25%     4.000000   3.000000
# 50%     4.000000   3.000000
# 75%     5.000000   3.750000
# max     5.000000   3.750000

# %%
df.isnull().head()
# Out:
#    Customer   Date  Flavor  Revenue  Profit
# 0     False  False   False    False   False
# 1     False  False   False    False   False
# 2     False  False   False    False   False
# 3     False  False   False    False   False
# 4     False  False   False    False   False

# %%
df = pd.read_excel('IceCreamDataSet.xlsx')
df.isnull().sum()
# Out:
# Customer    0
# Date        0
# Flavor      0
# Revenue     3
# Profit      4
# dtype: int64

# %%
df.set_index(np.arange(10,870,10),inplace= True)

# %%
df.head()
# Out:
#            Customer       Date     Flavor  Revenue  Profit
# 10  Dennis Perelman 2018-03-28  Chocolate      2.0     1.0
# 20       Don Frazon 2018-03-28    Vanilla      2.0     1.0
# 30    Drew Roulette 2018-03-28    Vanilla      2.0     1.0
# 40    Erin Davidson 2018-03-28    Vanilla      2.0     1.0
# 50   Ian Richardson 2018-03-28    Vanilla      2.0     1.0

# %%
df.reset_index(drop=True)
# Out:
#             Customer       Date          Flavor  Revenue  Profit
# 0    Dennis Perelman 2018-03-28       Chocolate      2.0    1.00
# 1         Don Frazon 2018-03-28         Vanilla      2.0    1.00
# 2      Drew Roulette 2018-03-28         Vanilla      2.0    1.00
# 3      Erin Davidson 2018-03-28         Vanilla      2.0    1.00
# 4     Ian Richardson 2018-03-28         Vanilla      2.0    1.00
# 5      Sean Lansfrow 2018-03-28         Vanilla      2.0    1.00
# 6      Sierra Noonan 2018-03-28       Chocolate      2.0    1.00
# 7     Silvio Carrera 2018-03-28         Vanilla      2.0     NaN
# 8     Silvio Carrera 2018-03-28         Vanilla      2.0    1.00
# 9          Ted Price 2018-03-28       Chocolate      2.0    1.00
# 10        Don Frazon 2018-03-28  Chocolate Chip      2.5    1.25
# 11     Erin Davidson 2018-03-28  Chocolate Chip      2.5    1.25
# 12  Malcolm Benjamin 2018-03-28  Chocolate Chip      2.5    1.25
# ...

# %%
df.head()
# Out:
#            Customer       Date     Flavor  Revenue  Profit
# 10  Dennis Perelman 2018-03-28  Chocolate      2.0     1.0
# 20       Don Frazon 2018-03-28    Vanilla      2.0     1.0
# 30    Drew Roulette 2018-03-28    Vanilla      2.0     1.0
# 40    Erin Davidson 2018-03-28    Vanilla      2.0     1.0
# 50   Ian Richardson 2018-03-28    Vanilla      2.0     1.0

# %%
len(df[10:100])
# Out:
# 76

# %%
df.append(df[10:100]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162 entries, 10 to 860
# Data columns (total 5 columns):
# Customer    162 non-null object
# Date        162 non-null datetime64[ns]
# Flavor      162 non-null object
# Revenue     156 non-null float64
# Profit      155 non-null float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 7.6+ KB

# %%
df.drop_duplicates(inplace=False, keep='first', subset=['Customer'])
# Out:
#              Customer       Date          Flavor  Revenue  Profit
# 10    Dennis Perelman 2018-03-28       Chocolate      2.0    1.00
# 20         Don Frazon 2018-03-28         Vanilla      2.0    1.00
# 30      Drew Roulette 2018-03-28         Vanilla      2.0    1.00
# 40      Erin Davidson 2018-03-28         Vanilla      2.0    1.00
# 50     Ian Richardson 2018-03-28         Vanilla      2.0    1.00
# 60      Sean Lansfrow 2018-03-28         Vanilla      2.0    1.00
# 70      Sierra Noonan 2018-03-28       Chocolate      2.0    1.00
# 80     Silvio Carrera 2018-03-28         Vanilla      2.0     NaN
# 100         Ted Price 2018-03-28       Chocolate      2.0    1.00
# 130  Malcolm Benjamin 2018-03-28  Chocolate Chip      2.5    1.25
# 140      Tony DiCenzo 2018-03-28  Chocolate Chip      2.5    1.25
# 640      Lila Stevens 2018-03-11    Cookie Dough      5.0    3.75

# %%
df.head()
# Out:
#            Customer       Date     Flavor  Revenue  Profit
# 10  Dennis Perelman 2018-03-28  Chocolate      2.0     1.0
# 20       Don Frazon 2018-03-28    Vanilla      2.0     1.0
# 30    Drew Roulette 2018-03-28    Vanilla      2.0     1.0
# 40    Erin Davidson 2018-03-28    Vanilla      2.0     1.0
# 50   Ian Richardson 2018-03-28    Vanilla      2.0     1.0

# %%
df.rename(columns={'Customer':'Cust'}).head()
# Out:
#                Cust       Date     Flavor  Revenue  Profit
# 10  Dennis Perelman 2018-03-28  Chocolate      2.0     1.0
# 20       Don Frazon 2018-03-28    Vanilla      2.0     1.0
# 30    Drew Roulette 2018-03-28    Vanilla      2.0     1.0
# 40    Erin Davidson 2018-03-28    Vanilla      2.0     1.0
# 50   Ian Richardson 2018-03-28    Vanilla      2.0     1.0

# %%
df.columns = [column.upper() for column in df.columns]

# %%
dlcol = list(df.columns)

# %%
type(dlcol)
# Out:
# list

# %%
type(df.columns.values.tolist())
# Out:
# list

# %%
df.isnull().sum()
# Out:
# CUSTOMER    0
# DATE        0
# FLAVOR      0
# REVENUE     3
# PROFIT      4
# dtype: int64

# %%
df.dropna(subset=['PROFIT'])
# Out:
#              CUSTOMER       DATE          FLAVOR  REVENUE  PROFIT
# 10    Dennis Perelman 2018-03-28       Chocolate      2.0    1.00
# 20         Don Frazon 2018-03-28         Vanilla      2.0    1.00
# 30      Drew Roulette 2018-03-28         Vanilla      2.0    1.00
# 40      Erin Davidson 2018-03-28         Vanilla      2.0    1.00
# 50     Ian Richardson 2018-03-28         Vanilla      2.0    1.00
# 60      Sean Lansfrow 2018-03-28         Vanilla      2.0    1.00
# 70      Sierra Noonan 2018-03-28       Chocolate      2.0    1.00
# 90     Silvio Carrera 2018-03-28         Vanilla      2.0    1.00
# 100         Ted Price 2018-03-28       Chocolate      2.0    1.00
# 110        Don Frazon 2018-03-28  Chocolate Chip      2.5    1.25
# 120     Erin Davidson 2018-03-28  Chocolate Chip      2.5    1.25
# 130  Malcolm Benjamin 2018-03-28  Chocolate Chip      2.5    1.25
# 140      Tony DiCenzo 2018-03-28  Chocolate Chip      2.5    1.25
# ...

# %%
df
# Out:
#              CUSTOMER       DATE          FLAVOR  REVENUE  PROFIT
# 10    Dennis Perelman 2018-03-28       Chocolate      2.0    1.00
# 20         Don Frazon 2018-03-28         Vanilla      2.0    1.00
# 30      Drew Roulette 2018-03-28         Vanilla      2.0    1.00
# 40      Erin Davidson 2018-03-28         Vanilla      2.0    1.00
# 50     Ian Richardson 2018-03-28         Vanilla      2.0    1.00
# 60      Sean Lansfrow 2018-03-28         Vanilla      2.0    1.00
# 70      Sierra Noonan 2018-03-28       Chocolate      2.0    1.00
# 80     Silvio Carrera 2018-03-28         Vanilla      2.0     NaN
# 90     Silvio Carrera 2018-03-28         Vanilla      2.0    1.00
# 100         Ted Price 2018-03-28       Chocolate      2.0    1.00
# 110        Don Frazon 2018-03-28  Chocolate Chip      2.5    1.25
# 120     Erin Davidson 2018-03-28  Chocolate Chip      2.5    1.25
# 130  Malcolm Benjamin 2018-03-28  Chocolate Chip      2.5    1.25
# ...

# %%
df.dropna(axis=1).head()
# Out:
#            CUSTOMER       DATE     FLAVOR
# 10  Dennis Perelman 2018-03-28  Chocolate
# 20       Don Frazon 2018-03-28    Vanilla
# 30    Drew Roulette 2018-03-28    Vanilla
# 40    Erin Davidson 2018-03-28    Vanilla
# 50   Ian Richardson 2018-03-28    Vanilla

# %%
df['REVENUE'].mean()
# Out:
# 4.0602409638554215

# %%
df['CUSTOMER'].describe()
# Out:
# count                86
# unique               12
# top       Sierra Noonan
# freq                 10
# Name: CUSTOMER, dtype: object

# %%
df['REVENUE'].describe()
# Out:
# count    83.000000
# mean      4.060241
# std       0.985868
# min       2.000000
# 25%       4.000000
# 50%       4.000000
# 75%       5.000000
# max       5.000000
# Name: REVENUE, dtype: float64

# %%
df['CUSTOMER'].value_counts()
# Out:
# Sierra Noonan       10
# Ted Price            9
# Sean Lansfrow        8
# Silvio Carrera       8
# Don Frazon           8
# Malcolm Benjamin     7
# Drew Roulette        7
# Ian Richardson       7
# Tony DiCenzo         7
# Erin Davidson        6
# Lila Stevens         5
# Dennis Perelman      4
# Name: CUSTOMER, dtype: int64

# %%
df_g = df.groupby('FLAVOR')

# %%
df_rev_fla =df.groupby('FLAVOR')['REVENUE'].mean()
df_rev_fla
# Out:
# FLAVOR
# Chocolate         3.727273
# Chocolate Chip    4.375000
# Cookie Dough      5.000000
# Mint Chip         5.000000
# Vanilla           3.461538
# Name: REVENUE, dtype: float64

# %%
df.groupby('FLAVOR')['REVENUE'].mean()['Chocolate']
# Out:
# 3.727272727272727

# %%
import numpy as np
df.isnull().sum()
# Out:
# CUSTOMER    0
# DATE        0
# FLAVOR      0
# REVENUE     3
# PROFIT      4
# dtype: int64

# %%
df[df['REVENUE'].isnull()]['FLAVOR']
# Out:
# 590    Chocolate Chip
# 650      Cookie Dough
# 800         Mint Chip
# Name: FLAVOR, dtype: object

# %%
df.iloc[0:4]
# Out:
#            CUSTOMER       DATE     FLAVOR  REVENUE  PROFIT
# 10  Dennis Perelman 2018-03-28  Chocolate      2.0     1.0
# 20       Don Frazon 2018-03-28    Vanilla      2.0     1.0
# 30    Drew Roulette 2018-03-28    Vanilla      2.0     1.0
# 40    Erin Davidson 2018-03-28    Vanilla      2.0     1.0

# %%
df[ (df['FLAVOR']=='Chocolate') | (df['FLAVOR']=='Vanilla')].sort_values('FLAVOR').head()
# Out:
#             CUSTOMER       DATE     FLAVOR  REVENUE  PROFIT
# 10   Dennis Perelman 2018-03-28  Chocolate      2.0     1.0
# 500        Ted Price 2018-03-31  Chocolate      4.0     3.0
# 490        Ted Price 2018-03-16  Chocolate      4.0     3.0
# 480        Ted Price 2018-03-02  Chocolate      4.0     3.0
# 470        Ted Price 2018-03-15  Chocolate      4.0     3.0

# %%
df[ df['FLAVOR'].isin(['Chocolate', 'Vanilla'])].head()
# Out:
#            CUSTOMER       DATE     FLAVOR  REVENUE  PROFIT
# 10  Dennis Perelman 2018-03-28  Chocolate      2.0     1.0
# 20       Don Frazon 2018-03-28    Vanilla      2.0     1.0
# 30    Drew Roulette 2018-03-28    Vanilla      2.0     1.0
# 40    Erin Davidson 2018-03-28    Vanilla      2.0     1.0
# 50   Ian Richardson 2018-03-28    Vanilla      2.0     1.0

# %%
df['day'] = df['DATE'].apply(lambda x : x.day)

# %%
df.head()
# Out:
#            CUSTOMER       DATE     FLAVOR  REVENUE  PROFIT  day
# 10  Dennis Perelman 2018-03-28  Chocolate      2.0     1.0   28
# 20       Don Frazon 2018-03-28    Vanilla      2.0     1.0   28
# 30    Drew Roulette 2018-03-28    Vanilla      2.0     1.0   28
# 40    Erin Davidson 2018-03-28    Vanilla      2.0     1.0   28
# 50   Ian Richardson 2018-03-28    Vanilla      2.0     1.0   28

# %%
df[(df['day']==28 ) & (df['FLAVOR'] == 'Chocolate')]
# Out:
#             CUSTOMER       DATE     FLAVOR  REVENUE  PROFIT  day
# 10   Dennis Perelman 2018-03-28  Chocolate      2.0     1.0   28
# 70     Sierra Noonan 2018-03-28  Chocolate      2.0     1.0   28
# 100        Ted Price 2018-03-28  Chocolate      2.0     1.0   28

# %%
list(df['FLAVOR'].unique())
# Out:
# ['Chocolate', 'Vanilla', 'Chocolate Chip', 'Cookie Dough', 'Mint Chip']

# %%
#day wise count
pd.DataFrame(df.groupby(['DATE','FLAVOR'])['FLAVOR'].count())
# Out:
#                            FLAVOR
# DATE       FLAVOR
# 2018-03-01 Chocolate            1
# 2018-03-02 Chocolate            1
#            Vanilla              2
# 2018-03-03 Chocolate            1
#            Cookie Dough         2
# 2018-03-04 Chocolate Chip       1
#            Cookie Dough         1
#            Vanilla              1
# 2018-03-06 Chocolate            1
#            Cookie Dough         1
# 2018-03-07 Cookie Dough         3
# 2018-03-08 Chocolate            1
#            Vanilla              2
# 2018-03-09 Chocolate            1
#            Chocolate Chip       1
# 2018-03-10 Chocolate            1
#            Chocolate Chip       1
#            Cookie Dough         1
#            Vanilla              1
# 2018-03-11 Chocolate            2
#            Chocolate Chip       1
#            Cookie Dough         2
#            Vanilla              1
# 2018-03-13 Chocolate Chip       1
#            Vanilla              1
# 2018-03-14 Vanilla              1
# ...

# %%
df_customer_profit = pd.DataFrame(df.groupby(['CUSTOMER','FLAVOR'])['PROFIT'].mean())
df_customer_profit
# Out:
#                                    PROFIT
# CUSTOMER         FLAVOR
# Dennis Perelman  Chocolate       2.000000
#                  Cookie Dough    3.750000
#                  Mint Chip       3.750000
# Don Frazon       Chocolate Chip  2.916667
#                  Mint Chip       3.750000
#                  Vanilla         2.333333
# Drew Roulette    Chocolate       3.000000
#                  Chocolate Chip  3.750000
#                  Cookie Dough    3.750000
#                  Vanilla         2.333333
# Erin Davidson    Chocolate Chip  1.250000
#                  Cookie Dough    3.750000
#                  Vanilla         2.333333
# Ian Richardson   Chocolate       3.000000
#                  Chocolate Chip  3.750000
#                  Vanilla         2.000000
# Lila Stevens     Cookie Dough    3.750000
# Malcolm Benjamin Chocolate       3.000000
#                  Chocolate Chip  2.916667
#                  Cookie Dough    3.750000
#                  Mint Chip       3.750000
# ...

# %%
df_customer_profit['PROFIT']['Dennis Perelman']['Chocolate']
# Out:
# 2.0

# %%
#flavor wise sale at each outlet
pd.DataFrame(df.groupby(['DATE'])['FLAVOR'].count().sort_values())
# Out:
#             FLAVOR
# DATE
# 2018-03-01       1
# 2018-03-21       1
# 2018-03-14       1
# 2018-03-22       1
# 2018-03-29       1
# 2018-03-27       1
# 2018-03-09       2
# 2018-03-06       2
# 2018-03-13       2
# 2018-03-30       2
# 2018-03-20       2
# 2018-03-08       3
# 2018-03-04       3
# 2018-03-03       3
# 2018-03-15       3
# 2018-03-25       3
# 2018-03-02       3
# 2018-03-07       3
# 2018-03-23       3
# 2018-03-24       4
# 2018-03-16       4
# 2018-03-10       4
# 2018-03-31       4
# 2018-03-17       5
# 2018-03-18       5
# 2018-03-11       6
# 2018-03-28      14

# %%
#aggregation at date and flavor level
pd.DataFrame(df.groupby(['DATE','FLAVOR'])['REVENUE','PROFIT'].sum())
# Out:
#                            REVENUE  PROFIT
# DATE       FLAVOR
# 2018-03-01 Chocolate           4.0    3.00
# 2018-03-02 Chocolate           4.0    3.00
#            Vanilla             8.0    6.00
# 2018-03-03 Chocolate           4.0    3.00
#            Cookie Dough       10.0    7.50
# 2018-03-04 Chocolate Chip      0.0    3.75
#            Cookie Dough        5.0    3.75
#            Vanilla             4.0    3.00
# 2018-03-06 Chocolate           4.0    3.00
#            Cookie Dough        5.0    3.75
# 2018-03-07 Cookie Dough       15.0   11.25
# 2018-03-08 Chocolate           4.0    3.00
#            Vanilla             8.0    6.00
# 2018-03-09 Chocolate           4.0    3.00
#            Chocolate Chip      5.0    3.75
# 2018-03-10 Chocolate           4.0    3.00
#            Chocolate Chip      5.0    3.75
#            Cookie Dough        5.0    3.75
#            Vanilla             4.0    3.00
# 2018-03-11 Chocolate           8.0    6.00
# ...

# %%
df2 = pd.DataFrame(df.groupby(['FLAVOR'])['PROFIT'].mean())
df2
# Out:
#                   PROFIT
# FLAVOR
# Chocolate       2.727273
# Chocolate Chip  3.161765
# Cookie Dough    3.750000
# Mint Chip       3.750000
# Vanilla         2.500000

# %%
df2['PROFIT']['Chocolate']
# Out:
# 2.727272727272727

# %%
df['PROFIT'].mean()
# Out:
# 2.9878048780487805

# %%
df_customer_profit["profitable"] = df_customer_profit["PROFIT"].apply(lambda x: 'yes' if x >=  df['PROFIT'].mean() else 'no')

# %%
df_customer_profit
# Out:
#                                    PROFIT better profit profitable
# CUSTOMER         FLAVOR
# Dennis Perelman  Chocolate       2.000000           bad         no
#                  Cookie Dough    3.750000          good        yes
#                  Mint Chip       3.750000          good        yes
# Don Frazon       Chocolate Chip  2.916667           bad         no
#                  Mint Chip       3.750000          good        yes
#                  Vanilla         2.333333           bad         no
# Drew Roulette    Chocolate       3.000000          good        yes
#                  Chocolate Chip  3.750000          good        yes
#                  Cookie Dough    3.750000          good        yes
#                  Vanilla         2.333333           bad         no
# Erin Davidson    Chocolate Chip  1.250000           bad         no
#                  Cookie Dough    3.750000          good        yes
#                  Vanilla         2.333333           bad         no
# ...

# %%
df_customer_profit[df_customer_profit['profitable']=='yes'].shape[0]
# Out:
# 25

# %%
df_customer_profit[df_customer_profit['profitable']=='no'].shape[0]
# Out:
# 12

# %%
df_customer_profit['profitable'].describe()
# Out:
# count      37
# unique      2
# top       yes
# freq       25
# Name: profitable, dtype: object
